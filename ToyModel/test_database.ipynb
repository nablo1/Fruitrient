# %%
import pandas as pd
import sqlite3
from sqlite3 import Error

#Create pandas df from csv train file
df = pd.read_csv('input/train.csv')

#Connect to DB
def db_connection(db_name):
    conn = None
    try:
        conn = sqlite3.connect(db_name)
        return conn
    except Error as e:
        print(e)
        
    return conn

db_conn = db_connection('test_db')
    
#Import data from train dataframe to database
df.to_sql(name='fruits', con=db_conn, if_exists='append')

# %%
fruits_train = pd.read_sql_query("SELECT * FROM fruits", db_conn)
fruits_train.head()
# Out:
#    index  type  pixel1  pixel2  pixel3  pixel4  pixel5  pixel6  pixel7  \
# 0      0     0     255     255     254     254     254     252     255
# 1      1     0     254     254     254     253     254     254     254
# 2      2     0     255     255     255     255     254     254     254
# 3      3     0     254     254     254     254     253     254     254
# 4      4     0     255     255     255     255     253     254     254
#
#    pixel8  ...  pixel775  pixel776  pixel777  pixel778  pixel779  pixel780  \
# 0     253  ...       242       255       255       255       255       255
# 1     255  ...       255       255       255       255       255       255
# 2     253  ...       255       255       255       255       255       255
# 3     254  ...       255       255       255       255       255       255
# 4     255  ...       255       255       255       255       255       255
#
#    pixel781  pixel782  pixel783  pixel784
# 0       255       255       255       255
# ...
